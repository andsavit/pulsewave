# %%
import json
import pandas as pd
import requests
import time
import os

# %%
path = "/Users/andrea/Progetti/strumenti_usato/data/reverb_categories.json"

# %%
with open(path) as f:
    raw = json.load(f)

# %%
data = raw['categories']

# %%
categories = []
for el in data:
    categories.append(el['name'])

# %%
categories_taxonomy = {}

for el in data:
    categories_taxonomy[el['name']] = [sub['name'] for sub in el['subcategories']]

categories_taxonomy
# Out:
# {'Accessori': ['Accordatori',
#   'Alimentatori',
#   'Altre corde',
#   'Borse per basso',
#   'Borse per chitarra',
#   'Capotasti',
#   'Case candy',
#   'Cavi',
#   'Corde per banjo',
#   'Corde per basso',
#   'Corde per chitarra',
#   'Corde per mandolino',
#   'Corde per ukulele',
#   'Cuffie',
#   'Custodie per amplificatori',
#   'Custodie per basso',
#   'Custodie per chitarra',
#   'Libri e DVD',
#   'Merchandise',
#   'Metronomo',
#   'Plettri',
#   'Sdoppiatori e adattatori per cavo',
#   'Slide',
#   'Strumenti',
#   'Supporti',
#   'Tracolle',
#   'Umidificatori'],
#  'Amplificatori': ['Amplificatori Bass per Cuffie',
#   'Amplificatori Chitarra per Pedaliere',
#   'Amplificatori boutique',
#   'Amplificatori di potenza per chitarra',
#   'Amplificatori per Bass Modeling',
#   'Amplificatori per Basso a Pedale',
#   'Amplificatori per chitarra a modellazione',
#   'Amplificatori per chitarra acustica',
#   'Amplificatori per cuffie per chitarra',
#   'Amplificatori per tastiera',
#   'Attenuatori per amplificatore',
#   'Cabinet per basso',
#   'Cabinet per chitarra',
#   'Combo per basso',
#   'Combo per chitarra',
#   'Drum Amps Elettronici ',
#   'Guitar Amp Stacks',
#   'Piccoli amplificatori',
#   'Preamplificatori per basso',
#   'Preamplificatori per chitarra',
#   'Stack Amp Basso',
#   'Testate per basso',
#   'Testate per chitarra'],
#  'Attrezzatura per DJ e luci': ['Consolle per DJ',
#   'Giradischi',
#   'Interfacce per DJ',
#   'Luci',
#   'Mixer',
#   'Sistemi per DJ all-in-one'],
#  'Bande e orchestre': ['Accessori per ottoni',
#   'Accessori per strumenti a corda',
#   'Accessori per strumenti a fiato',
#   'Arpe',
#   'Baritone',
#   'Clarinetti',
#   'Contrabbassi',
#   'Corni',
#   'Fagotti',
#   'Flauti',
#   'Oboi',
#   'Sassofoni',
#   'Trombe',
#   'Tromboni',
#   'Tube',
#   'Viole',
#   'Violini',
#   'Violoncelli'],
#  'Bassi': ['4 corde',
#   'A 5 corde o più',
#   'A scala corta',
#   'Bassi acustici',
#   'Elettroniche attive',
#   'Fretless',
#   'Per mancini'],
#  'Batterie e percussioni': ['Altro (splash, china, ecc.)',
#   'Bacchette e mallet',
#   'Cajon',
#   'Campane e glockenspiel',
#   'Chiavette batteria e accordatori',
#   'Congas e bonghi',
#   'Crash',
#   'Custodie e borse',
#   'Djembe',
#   'Gong',
#   'Grancassa',
#   'Grancasse da concerto',
#   'Grancasse da parata',
#   'Hi-hat',
#   'Kit acustici completi',
#   'Kit elettronici completi',
#   'Marimbe',
#   'Moduli',
#   'Pad controller',
#   'Pad da esercizio',
#   'Parti per batteria',
#   'Pedali',
#   'Percussione ausiliaria',
#   'Piatti da concerto',
#   'Piatti da parata',
#   'Ride',
#   'Rullante',
#   'Rullanti da concerto',
#   'Rullanti da parata',
#   'Set di piatti',
#   'Sgabelli',
#   'Shakers',
#   'Sostegni',
#   'Supporti',
#   'Testate',
#   'Timpani',
#   'Tom',
#   'Tom da concerto',
#   'Tom e tamburi tenori da parata',
#   'Vibrafoni',
#   'Xilofoni'],
#  'Chitarre acustiche': ['12 corde',
#   'Archtop',
#   'Baritone',
#   'Classiche',
#   'Da concerto',
#   'Dreadnought',
#   'Elettroniche attive',
#   'Jumbo',
#   'Mini/da viaggio',
#   'OM e auditorium',
#   'Parlor',
#   'Per mancini',
#   'Resonator',
#   'Tenore'],
#  'Chitarre elettriche': ['12 corde',
#   'Archtop',
#   'Baritone',
#   'Hollow body',
#   'Lap steel',
#   'Mini/da viaggio',
#   'Pedal steel',
#   'Per mancini',
#   'Semi hollow',
#   'Solid body',
#   'Tenore'],
#  'Effetti e pedali': ['Accordatori a pedale',
#   'Buffer',
#   'Chorus e vibrato',
#   'Compressione e sustain',
#   'Controller, volume e expression',
#   'Delay',
#   'Distorsione',
#   'Effetti per basso',
#   'Equalizzatore',
#   'Flanger',
#   'Fuzz',
#   'Generatori di rumore',
#   'Modulatori ad anello',
#   'Noise reduction e gate',
#   'Ottave e pitch',
#   'Overdrive e boost',
#   'Pedali looper e sampler',
#   'Pedaliere e alimentatori',
#   'Phase shifter',
#   'Preamplificatori',
#   'Reverb',
#   'Simulatori di amplificatori',
#   'Simulatori di cabinet',
#   'Synth per chitarra',
#   'Tremolo',
#   'Unità multieffetto',
#   'Vocale',
#   'Wah e filter'],
#  'Home audio': ['Amplificatori',
#   'Cavi',
#   'Convertitori DA',
#   'Cuffie aperte',
#   'Cuffie chiuse',
#   'Cuffie in-ear',
#   'Cuffie noise cancelling',
#   'Cuffie on-ear',
#   'Cuffie over-ear',
#   'Cuffie wireless',
#   'Diffusori da esterno',
#   'Diffusori da incasso',
#   'Diffusori da pavimento',
#   'Diffusori da scaffale',
#   'Diffusori surround e satellite',
#   'Diffusori wireless',
#   'Dispositivi per lo streaming',
#   'Distributori e diffusori di potenza',
#   'Equalizzatori',
#   'Giradischi',
#   'Lettori CD',
#   'Lettori digitali portatili',
#   'Media server',
#   'Parti e accessori per diffusori',
#   'Parti e accessori per giradischi',
#   'Parti per cuffie ed accessori',
#   'Piastre',
#   'Preamplificatori',
#   'Ricevitori',
#   'Sintonizzatori e radio',
#   'Sistemi di diffusione portatili',
#   'Sistemi stereo completi',
#   'Subwoofers'],
#  'Parti': ['Battipenna',
#   'Body per chitarra',
#   'Cordiere',
#   'Diffusori di ricambio',
#   'Manici',
#   'Manopole',
#   'Meccaniche',
#   'Parti per amplificatori',
#   'Parti per basso',
#   'Parti per pedale',
#   'Pickup per basso',
#   'Pickup per chitarra',
#   'Pickup per chitarre acustiche',
#   'Piroli per ponte',
#   'Ponti',
#   'Valvole'],
#  'Pro audio': ['Amplificatori di potenza',
#   'Channel strip',
#   'Compressori e limiter',
#   'Convertitori AD/DA',
#   'DI box',
#   'Delay',
#   'Diffusori attivi',
#   'Diffusori passivi',
#   'Equalizzatori',
#   'Gate ed expander',
#   'Interfacce',
#   'Microfoni',
#   'Mixer',
#   'Mixer attivi',
#   'Mobili per studio',
#   'Monitor da studio',
#   'Multieffetto',
#   'Patchbay',
#   'Preamplificatori per microfoni',
#   'Registratori portatili',
#   'Registrazione',
#   'Reverb',
#   'Ricevitori wireless',
#   'Serie 500',
#   'Sistemi PA portatili',
#   'Sistemi wireless per strumenti',
#   'Software su supporto fisico',
#   'Sommatori',
#   'Trasmettitori wireless',
#   'Utility'],
#  'Strumenti folkloristici': ['Armoniche',
#   'Armonium',
#   'Bajo quinto',
#   'Bajo sexto',
#   'Banjo',
#   'Fisarmoniche',
#   'Guitarrón',
#   'Mandolini',
#   'Oud',
#   'Shruti',
#   'Sitar',
#   'Ukulele',
#   'Vihuela'],
#  'Tastiere e synth': ['Alimentatori per sintetizzatori modulari',
#   'Borse per tastiera e synth',
#   'Campionatori',
#   'Controller MIDI per fiati',
#   'Controller MIDI per keytar',
#   'Controller MIDI per pad',
#   'Controller MIDI per pedali',
#   'Controller MIDI per tastiera',
#   'Cover per tastiera e synth',
#   'Cover per tastiera e synth',
#   'Custodie per sintetizzatori modulari',
#   'Drum machine',
#   'Eurorack',
#   'Groovebox',
#   'Moduli per sintetizzatori',
#   'Organi',
#   'Panche per tastiera e pianoforte',
#   'Pannelli vuoti per sintetizzatori modulari',
#   'Parti per tastiera e synth',
#   'Pedali Sustain per tastiera',
#   'Pianoforti',
#   'Pianoforti digitali da palco',
#   'Pianoforti digitali domestici',
#   'Pianoforti elettrici',
#   'Pianoforti verticali',
#   'Schede DSP per sintetizzatori modulari',
#   'Sequencer',
#   'Sistemi completi di sintetizzatori modulari',
#   'Splitter/hub per sintetizzatori modulari',
#   'Supporti per tastiera e synth',
#   'Synth a rack',
#   'Synth analogici',
#   'Synth desktop',
#   'Synth digitali',
#   'Synth per tastiera',
#   'Tastiere arranger',
#   'Tastiere per workstation',
#   'Tastiere portatili',
#   'Vocoder']}

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data.categories
#
# AttributeError: 'dict' object has no attribute 'categories'

# %% [markdown]
# # Stima numerosità categorie

# %%
BASE_URL = "https://reverb.com/"

cat_links = [] #link API categorie

for el in data:
    cat_links.append(el["_links"]['listings']['href'])

print(len(cat_links))
cat_links
# Out:
# 14
# ['/api/listings?product_type=accessories',
#  '/api/listings?product_type=amps',
#  '/api/listings?product_type=dj-and-lighting-gear',
#  '/api/listings?product_type=band-and-orchestra',
#  '/api/listings?product_type=bass-guitars',
#  '/api/listings?product_type=drums-and-percussion',
#  '/api/listings?product_type=acoustic-guitars',
#  '/api/listings?product_type=electric-guitars',
#  '/api/listings?product_type=effects-and-pedals',
#  '/api/listings?product_type=home-audio',
#  '/api/listings?product_type=parts',
#  '/api/listings?product_type=pro-audio',
#  '/api/listings?product_type=folk-instruments',
#  '/api/listings?product_type=keyboards-and-synths']

# %%
results = []  # qui accumuliamo i dati

headers = {
    "Authorization": f"Bearer {os.getenv('REVERB_TOKEN')}",
    "Accept-Version": "3.0"
}

for link in cat_links:
    try:
        response = requests.get(BASE_URL + link).json()
        total, cat = response['total'], response['humanized_params']
        
        # aggiungo un dizionario alla lista
        results.append({
            "link": link,
            "total": total,
            "params": cat
        })
        
        time.sleep(0.01)
    except Exception as e:
        print(f"Errore con {link}: {e}")

# creiamo il dataframe
df = pd.DataFrame(results)
# Out:
# Errore con /api/listings?product_type=electric-guitars: 'total'

# %%
df
# Out:
#                                                link   total  \
# 0            /api/listings?product_type=accessories  690515
# 1                   /api/listings?product_type=amps   70382
# 2   /api/listings?product_type=dj-and-lighting-gear   32522
# 3     /api/listings?product_type=band-and-orchestra   84904
# 4           /api/listings?product_type=bass-guitars   52697
# 5   /api/listings?product_type=drums-and-percussion  355343
# 6       /api/listings?product_type=acoustic-guitars  102342
# 7     /api/listings?product_type=effects-and-pedals  215765
# 8             /api/listings?product_type=home-audio   42844
# 9                  /api/listings?product_type=parts  385884
# 10             /api/listings?product_type=pro-audio  221361
# 11      /api/listings?product_type=folk-instruments   43899
# 12  /api/listings?product_type=keyboards-and-synths   89529
#
#                        params
# 0                 Accessories
# 1                        Amps
# 2        DJ and Lighting Gear
# 3            Band & Orchestra
# 4                Bass Guitars
# 5        Drums and Percussion
# 6            Acoustic Guitars
# 7   Guitar Pedals and Effects
# 8                  Home Audio
# 9                       Parts
# 10    Pro Audio and Recording
# 11           Folk Instruments
# 12       Keyboards and Synths

# %% [markdown]
# ## Script che usa la tabella

# %%
import time, random
import pandas as pd
import requests
from tqdm import tqdm

BASE = "https://api.reverb.com"
HEADERS = {
    "Accept": "application/hal+json",
    "Accept-Version": "3.0",
    "Accept-Language": "it-IT",
    "X-Display-Currency": "EUR",
    "X-Shipping-Region": "IT",
    # "Authorization": f"Bearer {TOKEN}",
    "User-Agent": "reverb-category-counter/0.1"
}

params = {
    "condition": "used"
}

def with_per_page_1(href: str) -> str: #asks for a simple result, we don't care
    sep = "&" if "?" in href else "?"
    url = f"{BASE}{href}"
    if "per_page=" not in url:
        url += f"{sep}per_page=1"
        sep = "&"
    if "page=" not in url:
        url += f"{sep}page=1"
    return url

def fetch_total(url: str, max_retries=6, base_delay=1.0, timeout=20.0):
    delay = base_delay
    for _ in range(max_retries):
        start = time.perf_counter()
        r = requests.get(url, headers=HEADERS, params=params, timeout=timeout)
        elapsed = time.perf_counter() - start

        # Rate limit
        if r.status_code == 429:
            wait = float(r.headers.get("Retry-After", delay))
            time.sleep(wait + random.random())
            delay = min(delay * 2, 60)
            continue
        # Server hiccup
        if 500 <= r.status_code < 600:
            time.sleep(delay + random.random())
            delay = min(delay * 2, 60)
            continue

        r.raise_for_status()
        data = r.json()
        return data.get("total"), elapsed
    return None, None

# ---- Example run ----
df = pd.read_csv("data/product_type-cat-href_table.csv")

totals, times = [], []
for i, row in tqdm(df.iterrows(), total=len(df)):
    url = with_per_page_1(row["listings_href"])
    total, elapsed = fetch_total(url)
    totals.append(total)
    times.append(elapsed)
    time.sleep(0.2)  # polite delay

df["total"] = totals
df["response_time"] = times
df["fetched_at"] = pd.Timestamp.utcnow()

print(f"Average response time: {pd.Series(times).mean():.2f} sec")
print(f"Median response time: {pd.Series(times).median():.2f} sec")
print(df.head())
# Out:
#   0%|          | 0/306 [00:00<?, ?it/s]
# 100%|██████████| 306/306 [05:04<00:00,  1.00it/s]
# Average response time: 0.79 sec
# Median response time: 0.63 sec
#   product_type         category  \
# 0  accessories           tuners
# 1  accessories   power-supplies
# 2  accessories    other-strings
# 3  accessories    bass-gig-bags
# 4  accessories  guitar-gig-bags
#
#                                        listings_href  total  response_time  \
# 0  /api/listings?category=tuners&product_type=acc...    836       0.568521
# 1  /api/listings?category=power-supplies&product_...    939       0.580544
# 2  /api/listings?category=other-strings&product_t...    154       0.548458
# 3  /api/listings?category=bass-gig-bags&product_t...    161       0.606473
# 4  /api/listings?category=guitar-gig-bags&product...    690       0.569765
#
#                         fetched_at
# 0 2025-09-01 13:20:16.063227+00:00
# 1 2025-09-01 13:20:16.063227+00:00
# 2 2025-09-01 13:20:16.063227+00:00
# 3 2025-09-01 13:20:16.063227+00:00
# 4 2025-09-01 13:20:16.063227+00:00

# %%
# Save both CSV and Parquet for convenience
df.to_csv("data/category_counts_used.csv", index=False)

"""
try:
    import pyarrow as pa, pyarrow.parquet as pq
    df.to_parquet("category_counts.parquet", index=False)
except Exception:
    pass
"""

print(df.head(10))
# Out:
#   product_type         category  \
# 0  accessories           tuners
# 1  accessories   power-supplies
# 2  accessories    other-strings
# 3  accessories    bass-gig-bags
# 4  accessories  guitar-gig-bags
# 5  accessories            capos
# 6  accessories       case-candy
# 7  accessories           cables
# 8  accessories    banjo-strings
# 9  accessories     bass-strings
#
#                                        listings_href  total  response_time  \
# 0  /api/listings?category=tuners&product_type=acc...    836       0.568521
# 1  /api/listings?category=power-supplies&product_...    939       0.580544
# 2  /api/listings?category=other-strings&product_t...    154       0.548458
# 3  /api/listings?category=bass-gig-bags&product_t...    161       0.606473
# 4  /api/listings?category=guitar-gig-bags&product...    690       0.569765
# 5  /api/listings?category=capos&product_type=acce...    206       0.585126
# 6  /api/listings?category=case-candy&product_type...   5780       0.573597
# 7  /api/listings?category=cables&product_type=acc...   5588       0.597923
# 8  /api/listings?category=banjo-strings&product_t...     37       0.602716
# 9  /api/listings?category=bass-strings&product_ty...    359       0.751865
#
#                         fetched_at
# 0 2025-09-01 13:20:16.063227+00:00
# 1 2025-09-01 13:20:16.063227+00:00
# 2 2025-09-01 13:20:16.063227+00:00
# 3 2025-09-01 13:20:16.063227+00:00
# 4 2025-09-01 13:20:16.063227+00:00
# 5 2025-09-01 13:20:16.063227+00:00
# 6 2025-09-01 13:20:16.063227+00:00
# 7 2025-09-01 13:20:16.063227+00:00
# 8 2025-09-01 13:20:16.063227+00:00
# 9 2025-09-01 13:20:16.063227+00:00

# %% [markdown]
# # Mapping and Product taxonomy table

# %%
#category mapping
cat_mapping = {}

for el in data:
    cat_mapping[el['slug']] = el

cat_mapping

for key in cat_mapping.keys():
    subcat_mapping = {}
    for subcat in cat_mapping[key]['subcategories']:
        cat_mapping[key][subcat_mapping][subcat['slug']] = subcat
# Out:
# {'accessories': {'name': 'Accessori',
#   'description': 'Whether your favorite cable has worn out or you need a snazzy new strap, Reverb has all of the accessories you could ever need to deck out your gear or rig. Hundreds of listings are posted on Reverb daily for brand new cables, strings, picks, cases, gig bags, straps, and a whole host of other music gear accessories.',
#   'subcategories': [{'name': 'Accordatori',
#     'description': '',
#     'id': 147,
#     'uuid': 'aff19d6a-ad5e-4b3b-b21c-8aa71ae834c6',
#     'full_name': 'Accessori / Accordatori',
#     'slug': 'tuners',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/tuners'},
#      'listings': {'href': '/api/listings?category=tuners&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/tuners'}}},
#    {'name': 'Alimentatori',
#     'description': '',
#     'id': 379,
#     'uuid': '1f7ab3de-1751-4e3f-9c08-f3173179f465',
#     'full_name': 'Accessori / Alimentatori',
#     'slug': 'power-supplies',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/power-supplies'},
#      'listings': {'href': '/api/listings?category=power-supplies&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/power-supplies'}}},
#    {'name': 'Altre corde',
#     'description': '',
#     'id': 188,
#     'uuid': '8dc53835-25c2-47a6-a51b-97a899d8ce2e',
#     'full_name': 'Accessori / Corde / Altre corde',
#     'slug': 'other-strings',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/other-strings'},
#      'listings': {'href': '/api/listings?category=other-strings&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/other-strings'}}},
#    {'name': 'Borse per basso',
#     'description': '',
#     'id': 211,
#     'uuid': 'ad1bc64f-ef22-4e54-a3fc-8db3cf038d35',
#     'full_name': 'Accessori / Custodie e borse / Borse per basso',
#     'slug': 'bass-gig-bags',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/bass-gig-bags'},
#      'listings': {'href': '/api/listings?category=bass-gig-bags&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/bass-gig-bags'}}},
#    {'name': 'Borse per chitarra',
#     'description': '',
#     'id': 209,
#     'uuid': '9f2edb74-fcd6-41a2-8d25-99222cc2577a',
#     'full_name': 'Accessori / Custodie e borse / Borse per chitarra',
#     'slug': 'guitar-gig-bags',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/guitar-gig-bags'},
#      'listings': {'href': '/api/listings?category=guitar-gig-bags&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/guitar-gig-bags'}}},
#    {'name': 'Capotasti',
#     'description': '',
#     'id': 214,
#     'uuid': '6c29a999-cc23-47b6-ade9-68a14b8e3149',
#     'full_name': 'Accessori / Capotasti',
#     'slug': 'capos',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/capos'},
#      'listings': {'href': '/api/listings?category=capos&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/capos'}}},
#    {'name': 'Case candy',
#     'description': '',
#     'id': 295,
#     'uuid': '5cb132e1-1a42-42f4-bcd1-cf17405e7aff',
#     'full_name': 'Accessori / Case candy',
#     'slug': 'case-candy',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/case-candy'},
#      'listings': {'href': '/api/listings?category=case-candy&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/case-candy'}}},
#    {'name': 'Cavi',
#     'description': '',
#     'id': 175,
#     'uuid': '516cfd7e-e745-44cf-bb72-053b3edcddaf',
#     'full_name': 'Accessori / Cavi',
#     'slug': 'cables',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/cables'},
#      'listings': {'href': '/api/listings?category=cables&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/cables'}}},
#    {'name': 'Corde per banjo',
#     'description': '',
#     'id': 185,
#     'uuid': 'af044b2e-88b9-4b3d-97f3-1d7b7c0831af',
#     'full_name': 'Accessori / Corde / Corde per banjo',
#     'slug': 'banjo-strings',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/banjo-strings'},
#      'listings': {'href': '/api/listings?category=banjo-strings&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/banjo-strings'}}},
#    {'name': 'Corde per basso',
#     'description': '',
#     'id': 184,
#     'uuid': 'd806bffe-8e7b-4be0-a80d-13dfb16db675',
#     'full_name': 'Accessori / Corde / Corde per basso',
#     'slug': 'bass-strings',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/bass-strings'},
#      'listings': {'href': '/api/listings?category=bass-strings&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/bass-strings'}}},
#    {'name': 'Corde per chitarra',
#     'description': '',
#     'id': 183,
#     'uuid': 'df6f1f19-e67e-42c7-b00b-608cb577edf4',
#     'full_name': 'Accessori / Corde / Corde per chitarra',
#     'slug': 'guitar-strings',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/guitar-strings'},
#      'listings': {'href': '/api/listings?category=guitar-strings&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/guitar-strings'}}},
#    {'name': 'Corde per mandolino',
#     'description': '',
#     'id': 186,
#     'uuid': 'c584855a-319b-46c8-9578-489325c9318c',
#     'full_name': 'Accessori / Corde / Corde per mandolino',
#     'slug': 'mandolin-strings',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/mandolin-strings'},
#      'listings': {'href': '/api/listings?category=mandolin-strings&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/mandolin-strings'}}},
#    {'name': 'Corde per ukulele',
#     'description': '',
#     'id': 187,
#     'uuid': 'a119407f-1192-42c9-93f1-d59e952f9917',
#     'full_name': 'Accessori / Corde / Corde per ukulele',
#     'slug': 'ukulele-strings',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/ukulele-strings'},
#      'listings': {'href': '/api/listings?category=ukulele-strings&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/ukulele-strings'}}},
#    {'name': 'Cuffie',
#     'description': '',
#     'id': 229,
#     'uuid': '5004a624-03c4-436b-81bf-78a108eb595d',
#     'full_name': 'Accessori / Cuffie',
#     'slug': 'headphones',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/headphones'},
#      'listings': {'href': '/api/listings?category=headphones&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/headphones'}}},
#    {'name': 'Custodie per amplificatori',
#     'description': '',
#     'id': 251,
#     'uuid': 'cdadd9b5-9d6d-4193-b0ee-b94d9ffd02ec',
#     'full_name': 'Accessori / Custodie per amplificatori',
#     'slug': 'amp-covers',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/amp-covers'},
#      'listings': {'href': '/api/listings?category=amp-covers&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/amp-covers'}}},
#    {'name': 'Custodie per basso',
#     'description': '',
#     'id': 210,
#     'uuid': 'bd397c15-0cf3-4c6f-8005-7b8309ced1c4',
#     'full_name': 'Accessori / Custodie e borse / Custodie per basso',
#     'slug': 'bass-cases',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/bass-cases'},
#      'listings': {'href': '/api/listings?category=bass-cases&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/bass-cases'}}},
#    {'name': 'Custodie per chitarra',
#     'description': '',
#     'id': 55,
#     'uuid': 'b1f4ce46-26e5-4f27-8b8a-66bd0f41a8eb',
#     'full_name': 'Accessori / Custodie e borse / Custodie per chitarra',
#     'slug': 'guitar-cases',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/guitar-cases'},
#      'listings': {'href': '/api/listings?category=guitar-cases&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/guitar-cases'}}},
#    {'name': 'Libri e DVD',
#     'description': '',
#     'id': 220,
#     'uuid': '7681b711-435c-4923-bdc3-65076d15d78c',
#     'full_name': 'Accessori / Libri e DVD',
#     'slug': 'books-and-dvds',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/books-and-dvds'},
#      'listings': {'href': '/api/listings?category=books-and-dvds&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/books-and-dvds'}}},
#    {'name': 'Merchandise',
#     'description': '',
#     'id': 227,
#     'uuid': '22af0079-d5e7-48d1-9e5c-108105a2156c',
#     'full_name': 'Accessori / Merchandise',
#     'slug': 'merchandise',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/merchandise'},
#      'listings': {'href': '/api/listings?category=merchandise&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/merchandise'}}},
#    {'name': 'Metronomo',
#     'description': '',
#     'id': 238,
#     'uuid': '0fa6ff05-bfb7-4b1c-913c-0b66f2897fbc',
#     'full_name': 'Accessori / Metronomo',
#     'slug': 'metronome',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/metronome'},
#      'listings': {'href': '/api/listings?category=metronome&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/metronome'}}},
#    {'name': 'Plettri',
#     'description': '',
#     'id': 150,
#     'uuid': '98a45e2d-2cc2-4b17-b695-a5d198c8f6d3',
#     'full_name': 'Accessori / Plettri',
#     'slug': 'picks',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/picks'},
#      'listings': {'href': '/api/listings?category=picks&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/picks'}}},
#    {'name': 'Sdoppiatori e adattatori per cavo',
#     'description': '',
#     'id': 445,
#     'uuid': '58e4378e-545b-441b-844d-e171025101d5',
#     'full_name': 'Accessori / Sdoppiatori e adattatori per cavo',
#     'slug': 'cable-adapters-and-splitters',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/cable-adapters-and-splitters'},
#      'listings': {'href': '/api/listings?category=cable-adapters-and-splitters&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/cable-adapters-and-splitters'}}},
#    {'name': 'Slide',
#     'description': '',
#     'id': 392,
#     'uuid': 'f5b5d030-51db-0134-7b64-2cbc3295deb9',
#     'full_name': 'Accessori / Slide',
#     'slug': 'slides',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/slides'},
#      'listings': {'href': '/api/listings?category=slides&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/slides'}}},
#    {'name': 'Strumenti',
#     'description': '',
#     'id': 228,
#     'uuid': '4ca6d5e9-f00f-468d-bcae-8c7497537281',
#     'full_name': 'Accessori / Strumenti',
#     'slug': 'tools',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/tools'},
#      'listings': {'href': '/api/listings?category=tools&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/tools'}}},
#    {'name': 'Supporti',
#     'description': '',
#     'id': 213,
#     'uuid': 'bb1ca93f-5dcc-48ec-adad-77d22f61b588',
#     'full_name': 'Accessori / Supporti',
#     'slug': 'stands',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/stands'},
#      'listings': {'href': '/api/listings?category=stands&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/stands'}}},
#    {'name': 'Tracolle',
#     'description': '',
#     'id': 137,
#     'uuid': '1b357626-300e-47dd-85b0-bf657bca1a96',
#     'full_name': 'Accessori / Tracolle',
#     'slug': 'straps',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/straps'},
#      'listings': {'href': '/api/listings?category=straps&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/straps'}}},
#    {'name': 'Umidificatori',
#     'description': '',
#     'id': 225,
#     'uuid': '797faee0-04fd-4998-954d-83c88c8e8527',
#     'full_name': 'Accessori / Umidificatori',
#     'slug': 'humidifiers',
#     'product_type_slug': 'accessories',
#     'root_uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/accessories/humidifiers'},
#      'listings': {'href': '/api/listings?category=humidifiers&product_type=accessories'},
#      'follow': {'href': '/api/my/follows/categories/accessories/humidifiers'}}}],
#   'id': 28,
#   'uuid': '62835d2e-ac92-41fc-9b8d-4aba8c1c25d5',
#   'slug': 'accessories',
#   '_links': {'image': {'href': 'https://rvb-img.reverb.com/image/upload/s--kSXOef0b--/f_auto,t_large/v1434468134/nswuzgshwnskj9nxxtdn.png'},
#    'self': {'href': '/api/categories/accessories'},
#    'listings': {'href': '/api/listings?product_type=accessories'},
#    'follow': {'href': '/api/my/follows/categories/accessories'}}},
#  'amps': {'name': 'Amplificatori',
#   'description': "For as long as there have been electric instruments, there have been amplifiers to plug them into. Today's market offers a wider selection than ever before with fantastic options for acoustic and electric guitars, basses, keyboards and really anything with an output jack. For guitars in particular, the range of options is extremely diverse with everything from vintage combo amps from Fender and Vox to modern boutique heads from the likes of Dr. Z. No matter what sort of music you play and what type of instrument you play it on, you can find your dream amp here on Reverb.",
#   'subcategories': [{'name': 'Amplificatori Bass per Cuffie',
#     'description': '',
#     'id': 484,
#     'uuid': '7eb7606e-ea45-4097-9d35-2c35928f283b',
#     'full_name': 'Amplificatori / Amplificatori basso / Amplificatori Bass per Cuffie',
#     'slug': 'bass-headphone-amps',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/bass-headphone-amps'},
#      'listings': {'href': '/api/listings?category=bass-headphone-amps&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/bass-headphone-amps'}}},
#    {'name': 'Amplificatori Chitarra per Pedaliere',
#     'description': '',
#     'id': 495,
#     'uuid': '0aecdeda-b984-4c33-b98d-836d4bc50f1a',
#     'full_name': 'Amplificatori / Amplificatori chitarra / Amplificatori Chitarra per Pedaliere',
#     'slug': 'pedalboard-guitar-amps',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/pedalboard-guitar-amps'},
#      'listings': {'href': '/api/listings?category=pedalboard-guitar-amps&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/pedalboard-guitar-amps'}}},
#    {'name': 'Amplificatori boutique',
#     'description': '',
#     'id': 174,
#     'uuid': '4ca4f473-567f-46b0-8b66-9936a1179cd6',
#     'full_name': 'Amplificatori / Amplificatori boutique',
#     'slug': 'boutique-amps',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/boutique-amps'},
#      'listings': {'href': '/api/listings?category=boutique-amps&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/boutique-amps'}}},
#    {'name': 'Amplificatori di potenza per chitarra',
#     'description': '',
#     'id': 494,
#     'uuid': 'acea3069-47ba-4371-bc83-fafc02a573ed',
#     'full_name': 'Amplificatori / Amplificatori chitarra / Amplificatori di potenza per chitarra',
#     'slug': 'guitar-power-amps',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/guitar-power-amps'},
#      'listings': {'href': '/api/listings?category=guitar-power-amps&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/guitar-power-amps'}}},
#    {'name': 'Amplificatori per Bass Modeling',
#     'description': '',
#     'id': 485,
#     'uuid': 'b8a67a39-3e5d-4b0c-8482-167325bad21f',
#     'full_name': 'Amplificatori / Amplificatori basso / Amplificatori per Bass Modeling',
#     'slug': 'bass-modeling-amps',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/bass-modeling-amps'},
#      'listings': {'href': '/api/listings?category=bass-modeling-amps&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/bass-modeling-amps'}}},
#    {'name': 'Amplificatori per Basso a Pedale',
#     'description': '',
#     'id': 487,
#     'uuid': '3479c78b-e28f-44c9-b5e8-8fc0c75cd130',
#     'full_name': 'Amplificatori / Amplificatori basso / Amplificatori per Basso a Pedale',
#     'slug': 'pedalboard-bass-amps',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/pedalboard-bass-amps'},
#      'listings': {'href': '/api/listings?category=pedalboard-bass-amps&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/pedalboard-bass-amps'}}},
#    {'name': 'Amplificatori per chitarra a modellazione',
#     'description': '',
#     'id': 376,
#     'uuid': '0338462f-285a-4273-afde-47c4fc752e3f',
#     'full_name': 'Amplificatori / Amplificatori chitarra / Amplificatori per chitarra a modellazione',
#     'slug': 'guitar-modeling-amps',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/guitar-modeling-amps'},
#      'listings': {'href': '/api/listings?category=guitar-modeling-amps&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/guitar-modeling-amps'}}},
#    {'name': 'Amplificatori per chitarra acustica',
#     'description': '',
#     'id': 230,
#     'uuid': '100a3e13-4d9c-4ee6-b093-d464b101f26e',
#     'full_name': 'Amplificatori / Amplificatori chitarra / Amplificatori per chitarra acustica',
#     'slug': 'acoustic-guitar-amps',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/acoustic-guitar-amps'},
#      'listings': {'href': '/api/listings?category=acoustic-guitar-amps&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/acoustic-guitar-amps'}}},
#    {'name': 'Amplificatori per cuffie per chitarra',
#     'description': '',
#     'id': 492,
#     'uuid': '7b5304ca-9b67-4b5c-a8a4-f72838d58ddb',
#     'full_name': 'Amplificatori / Amplificatori chitarra / Amplificatori per cuffie per chitarra',
#     'slug': 'guitar-headphone-amps',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/guitar-headphone-amps'},
#      'listings': {'href': '/api/listings?category=guitar-headphone-amps&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/guitar-headphone-amps'}}},
#    {'name': 'Amplificatori per tastiera',
#     'description': '',
#     'id': 123,
#     'uuid': 'bfaedcbb-d128-4f5e-b708-d475c6c32277',
#     'full_name': 'Amplificatori / Amplificatori per tastiera',
#     'slug': 'keyboard-amps',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/keyboard-amps'},
#      'listings': {'href': '/api/listings?category=keyboard-amps&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/keyboard-amps'}}},
#    {'name': 'Attenuatori per amplificatore',
#     'description': '',
#     'id': 221,
#     'uuid': '4069c185-c9a4-4354-b09f-31e83fbde2f1',
#     'full_name': 'Amplificatori / Attenuatori per amplificatore',
#     'slug': 'amp-attenuators',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/amp-attenuators'},
#      'listings': {'href': '/api/listings?category=amp-attenuators&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/amp-attenuators'}}},
#    {'name': 'Cabinet per basso',
#     'description': '',
#     'id': 42,
#     'uuid': '6c664a95-048a-4795-b0ad-c7c03d9eee4c',
#     'full_name': 'Amplificatori / Amplificatori basso / Cabinet per basso',
#     'slug': 'bass-cabinets',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/bass-cabinets'},
#      'listings': {'href': '/api/listings?category=bass-cabinets&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/bass-cabinets'}}},
#    {'name': 'Cabinet per chitarra',
#     'description': '',
#     'id': 39,
#     'uuid': 'f1b3d127-4158-43c3-934b-e402adc3d6ca',
#     'full_name': 'Amplificatori / Amplificatori chitarra / Cabinet per chitarra',
#     'slug': 'guitar-cabinets',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/guitar-cabinets'},
#      'listings': {'href': '/api/listings?category=guitar-cabinets&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/guitar-cabinets'}}},
#    {'name': 'Combo per basso',
#     'description': '',
#     'id': 40,
#     'uuid': '052c7288-b2e0-42d2-8927-2c9176ef1699',
#     'full_name': 'Amplificatori / Amplificatori basso / Combo per basso',
#     'slug': 'bass-combos',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/bass-combos'},
#      'listings': {'href': '/api/listings?category=bass-combos&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/bass-combos'}}},
#    {'name': 'Combo per chitarra',
#     'description': '',
#     'id': 37,
#     'uuid': '10335451-31e5-418a-8ed8-f48cd738f17d',
#     'full_name': 'Amplificatori / Amplificatori chitarra / Combo per chitarra',
#     'slug': 'guitar-combos',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/guitar-combos'},
#      'listings': {'href': '/api/listings?category=guitar-combos&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/guitar-combos'}}},
#    {'name': 'Drum Amps Elettronici ',
#     'description': '',
#     'id': 489,
#     'uuid': 'dec239d9-e548-4f80-b1ab-42498344ee8c',
#     'full_name': 'Amplificatori / Drum Amps Elettronici ',
#     'slug': 'electronic-drum-amps',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/electronic-drum-amps'},
#      'listings': {'href': '/api/listings?category=electronic-drum-amps&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/electronic-drum-amps'}}},
#    {'name': 'Guitar Amp Stacks',
#     'description': '',
#     'id': 491,
#     'uuid': '66d136cb-02f2-4d04-b617-9215e972cc29',
#     'full_name': 'Amplificatori / Amplificatori chitarra / Guitar Amp Stacks',
#     'slug': 'guitar-amp-stacks',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/guitar-amp-stacks'},
#      'listings': {'href': '/api/listings?category=guitar-amp-stacks&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/guitar-amp-stacks'}}},
#    {'name': 'Piccoli amplificatori',
#     'description': '',
#     'id': 231,
#     'uuid': 'edd6e048-a378-4f6f-b2b5-dd46016c6118',
#     'full_name': 'Amplificatori / Piccoli amplificatori',
#     'slug': 'small-amps',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/small-amps'},
#      'listings': {'href': '/api/listings?category=small-amps&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/small-amps'}}},
#    {'name': 'Preamplificatori per basso',
#     'description': '',
#     'id': 486,
#     'uuid': '8cdb3e94-9cfa-4b1b-9da5-84fcc4ca1b20',
#     'full_name': 'Amplificatori / Amplificatori basso / Preamplificatori per basso',
#     'slug': 'bass-preamps',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/bass-preamps'},
#      'listings': {'href': '/api/listings?category=bass-preamps&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/bass-preamps'}}},
#    {'name': 'Preamplificatori per chitarra',
#     'description': '',
#     'id': 493,
#     'uuid': 'b6722b4b-4a2b-4d8f-82e9-0eacd20841aa',
#     'full_name': 'Amplificatori / Amplificatori chitarra / Preamplificatori per chitarra',
#     'slug': 'guitar-preamps',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/guitar-preamps'},
#      'listings': {'href': '/api/listings?category=guitar-preamps&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/guitar-preamps'}}},
#    {'name': 'Stack Amp Basso',
#     'description': '',
#     'id': 483,
#     'uuid': '1da66654-d83b-4632-a481-c306b1402a73',
#     'full_name': 'Amplificatori / Amplificatori basso / Stack Amp Basso',
#     'slug': 'bass-amp-stacks',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/bass-amp-stacks'},
#      'listings': {'href': '/api/listings?category=bass-amp-stacks&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/bass-amp-stacks'}}},
#    {'name': 'Testate per basso',
#     'description': '',
#     'id': 41,
#     'uuid': '892aa8b2-a209-49db-8ad2-eed758025a9d',
#     'full_name': 'Amplificatori / Amplificatori basso / Testate per basso',
#     'slug': 'bass-heads',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/bass-heads'},
#      'listings': {'href': '/api/listings?category=bass-heads&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/bass-heads'}}},
#    {'name': 'Testate per chitarra',
#     'description': '',
#     'id': 38,
#     'uuid': '19d53222-297e-410c-ba4f-b48678e917f9',
#     'full_name': 'Amplificatori / Amplificatori chitarra / Testate per chitarra',
#     'slug': 'guitar-heads',
#     'product_type_slug': 'amps',
#     'root_uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/amps/guitar-heads'},
#      'listings': {'href': '/api/listings?category=guitar-heads&product_type=amps'},
#      'follow': {'href': '/api/my/follows/categories/amps/guitar-heads'}}}],
#   'id': 15,
#   'uuid': '09055aa7-ed49-459d-9452-aa959f288dc2',
#   'slug': 'amps',
#   '_links': {'image': {'href': 'https://rvb-img.reverb.com/image/upload/s--9yOTS_dE--/f_auto,t_large/v1434468023/dmkxpiabvd6pobhgdijw.png'},
#    'self': {'href': '/api/categories/amps'},
#    'listings': {'href': '/api/listings?product_type=amps'},
#    'follow': {'href': '/api/my/follows/categories/amps'}}},
#  'dj-and-lighting-gear': {'name': 'Attrezzatura per DJ e luci',
#   'description': 'Modern DJ performances have evolved a long way from two turntables and a microphone. From integrated controllers that push the boundaries of remixing to cutting edge software that takes mixing tracks to a new level, the tools of the trade are powerful, numerous and sophisticated. Ableton, Native Instruments Traktor, Serato and more offer a huge spectrum of options for finding your own style of DJing, production and beat making. Visual software and DMX controllers let you bring audio synced projections and sophisticated lighting rigs to life, giving your tracks a whole new dimension. \n\nReverb is the best place to start or upgrade your DJ setup with everything from the latest and greatest digital tools to classic CDJs and turntables from Technics and Pioneer.',
#   'subcategories': [{'name': 'Consolle per DJ',
#     'description': '',
#     'id': 245,
#     'uuid': '5737678f-8d15-4df2-b402-869d5bfc04bd',
#     'full_name': 'Attrezzatura per DJ e luci / Consolle per DJ',
#     'slug': 'dj-controllers',
#     'product_type_slug': 'dj-and-lighting-gear',
#     'root_uuid': '58d889f7-0aa1-4689-a9d3-da16dd225e8d',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/dj-and-lighting-gear/dj-controllers'},
#      'listings': {'href': '/api/listings?category=dj-controllers&product_type=dj-and-lighting-gear'},
#      'follow': {'href': '/api/my/follows/categories/dj-and-lighting-gear/dj-controllers'}}},
#    {'name': 'Giradischi',
#     'description': '',
#     'id': 246,
#     'uuid': 'f8c37b8b-a8c6-4967-a2a4-7d50717a52ab',
#     'full_name': 'Attrezzatura per DJ e luci / Giradischi',
#     'slug': 'turntables',
#     'product_type_slug': 'dj-and-lighting-gear',
#     'root_uuid': '58d889f7-0aa1-4689-a9d3-da16dd225e8d',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/dj-and-lighting-gear/turntables'},
#      'listings': {'href': '/api/listings?category=turntables&product_type=dj-and-lighting-gear'},
#      'follow': {'href': '/api/my/follows/categories/dj-and-lighting-gear/turntables'}}},
#    {'name': 'Interfacce per DJ',
#     'description': '',
#     'id': 247,
#     'uuid': '4bf02b52-1389-4c07-af81-8e73f4eebaa0',
#     'full_name': 'Attrezzatura per DJ e luci / Interfacce per DJ',
#     'slug': 'dj-interfaces',
#     'product_type_slug': 'dj-and-lighting-gear',
#     'root_uuid': '58d889f7-0aa1-4689-a9d3-da16dd225e8d',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/dj-and-lighting-gear/dj-interfaces'},
#      'listings': {'href': '/api/listings?category=dj-interfaces&product_type=dj-and-lighting-gear'},
#      'follow': {'href': '/api/my/follows/categories/dj-and-lighting-gear/dj-interfaces'}}},
#    {'name': 'Luci',
#     'description': '',
#     'id': 250,
#     'uuid': '87581b0b-de93-49c2-9fe5-6ac5e62987f0',
#     'full_name': 'Attrezzatura per DJ e luci / Luci',
#     'slug': 'lighting',
#     'product_type_slug': 'dj-and-lighting-gear',
#     'root_uuid': '58d889f7-0aa1-4689-a9d3-da16dd225e8d',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/dj-and-lighting-gear/lighting'},
#      'listings': {'href': '/api/listings?category=lighting&product_type=dj-and-lighting-gear'},
#      'follow': {'href': '/api/my/follows/categories/dj-and-lighting-gear/lighting'}}},
#    {'name': 'Mixer',
#     'description': '',
#     'id': 248,
#     'uuid': 'd007c1a2-be03-4d5a-b2df-182a0da41271',
#     'full_name': 'Attrezzatura per DJ e luci / Mixer',
#     'slug': 'mixers',
#     'product_type_slug': 'dj-and-lighting-gear',
#     'root_uuid': '58d889f7-0aa1-4689-a9d3-da16dd225e8d',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/dj-and-lighting-gear/mixers'},
#      'listings': {'href': '/api/listings?category=mixers&product_type=dj-and-lighting-gear'},
#      'follow': {'href': '/api/my/follows/categories/dj-and-lighting-gear/mixers'}}},
#    {'name': 'Sistemi per DJ all-in-one',
#     'description': '',
#     'id': 249,
#     'uuid': '1c65040a-6cca-4834-985e-44b2b29c14c1',
#     'full_name': 'Attrezzatura per DJ e luci / Sistemi per DJ all-in-one',
#     'slug': 'all-in-one-dj-systems',
#     'product_type_slug': 'dj-and-lighting-gear',
#     'root_uuid': '58d889f7-0aa1-4689-a9d3-da16dd225e8d',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/dj-and-lighting-gear/all-in-one-dj-systems'},
#      'listings': {'href': '/api/listings?category=all-in-one-dj-systems&product_type=dj-and-lighting-gear'},
#      'follow': {'href': '/api/my/follows/categories/dj-and-lighting-gear/all-in-one-dj-systems'}}}],
#   'id': 30,
#   'uuid': '58d889f7-0aa1-4689-a9d3-da16dd225e8d',
#   'slug': 'dj-and-lighting-gear',
#   '_links': {'image': {'href': 'https://rvb-img.reverb.com/image/upload/s---h0uwx58--/f_auto,t_large/v1434468156/qsegelbnw3atc4zaimcu.png'},
#    'self': {'href': '/api/categories/dj-and-lighting-gear'},
#    'listings': {'href': '/api/listings?product_type=dj-and-lighting-gear'},
#    'follow': {'href': '/api/my/follows/categories/dj-and-lighting-gear'}}},
#  'band-and-orchestra': {'name': 'Bande e orchestre',
#   'description': "Whether you're a student picking up your first trumpet or a seasoned symphony pro looking for that one-of-a-kind violin, there's nothing quite like a new string or wind instrument. From beginner level horns to fine antique cellos, you can find all manner of band and orchestra instruments and accessories for sale here on Reverb. Browse our massive selection from brands like Yamaha, Selmer, Bach and more, and find deals on  new and used band and orchestra instruments here.",
#   'subcategories': [{'name': 'Accessori per ottoni',
#     'description': '',
#     'id': 292,
#     'uuid': 'dcd03dd7-e1bf-4fb9-84a5-0e5126a3fc64',
#     'full_name': 'Bande e orchestre / Ottone / Accessori per ottoni',
#     'slug': 'brass-accessories',
#     'product_type_slug': 'band-and-orchestra',
#     'root_uuid': '032c74d0-b0e2-4442-877f-e1a22438a7fa',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/band-and-orchestra/brass-accessories'},
#      'listings': {'href': '/api/listings?category=brass-accessories&product_type=band-and-orchestra'},
#      'follow': {'href': '/api/my/follows/categories/band-and-orchestra/brass-accessories'}}},
#    {'name': 'Accessori per strumenti a corda',
#     'description': '',
#     'id': 291,
#     'uuid': 'ac90b7da-303f-4219-b6ea-3270d63d6a05',
#     'full_name': 'Bande e orchestre / Strumenti a corda / Accessori per strumenti a corda',
#     'slug': 'string-accessories',
#     'product_type_slug': 'band-and-orchestra',
#     'root_uuid': '032c74d0-b0e2-4442-877f-e1a22438a7fa',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/band-and-orchestra/string-accessories'},
#      'listings': {'href': '/api/listings?category=string-accessories&product_type=band-and-orchestra'},
#      'follow': {'href': '/api/my/follows/categories/band-and-orchestra/string-accessories'}}},
#    {'name': 'Accessori per strumenti a fiato',
#     'description': '',
#     'id': 293,
#     'uuid': '0aa66738-2512-4952-8626-4edec26c7a01',
#     'full_name': 'Bande e orchestre / Strumenti a fiato / Accessori per strumenti a fiato',
#     'slug': 'woodwind-accessories',
#     'product_type_slug': 'band-and-orchestra',
#     'root_uuid': '032c74d0-b0e2-4442-877f-e1a22438a7fa',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/band-and-orchestra/woodwind-accessories'},
#      'listings': {'href': '/api/listings?category=woodwind-accessories&product_type=band-and-orchestra'},
#      'follow': {'href': '/api/my/follows/categories/band-and-orchestra/woodwind-accessories'}}},
#    {'name': 'Arpe',
#     'description': '',
#     'id': 173,
#     'uuid': 'ef040ff3-b7fc-4dc2-bcde-fb3d3f27d170',
#     'full_name': 'Bande e orchestre / Strumenti a corda / Arpe',
#     'slug': 'harps',
#     'product_type_slug': 'band-and-orchestra',
#     'root_uuid': '032c74d0-b0e2-4442-877f-e1a22438a7fa',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/band-and-orchestra/harps'},
#      'listings': {'href': '/api/listings?category=harps&product_type=band-and-orchestra'},
#      'follow': {'href': '/api/my/follows/categories/band-and-orchestra/harps'}}},
#    {'name': 'Baritone',
#     'description': '',
#     'id': 374,
#     'uuid': 'aefe60d2-6b9e-461c-9952-85d084f4b919',
#     'full_name': 'Bande e orchestre / Ottone / Baritone',
#     'slug': 'baritone',
#     'product_type_slug': 'band-and-orchestra',
#     'root_uuid': '032c74d0-b0e2-4442-877f-e1a22438a7fa',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/band-and-orchestra/baritone'},
#      'listings': {'href': '/api/listings?category=baritone&product_type=band-and-orchestra'},
#      'follow': {'href': '/api/my/follows/categories/band-and-orchestra/baritone'}}},
#    {'name': 'Clarinetti',
#     'description': '',
#     'id': 165,
#     'uuid': 'fa60a987-584a-4731-9471-99d90c45a4d3',
#     'full_name': 'Bande e orchestre / Strumenti a fiato / Clarinetti',
#     'slug': 'clarinets',
# ...
#      'self': {'href': '/api/categories/keyboards-and-synths/keyboard-sustain-pedals'},
#      'listings': {'href': '/api/listings?category=keyboard-sustain-pedals&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/keyboard-sustain-pedals'}}},
#    {'name': 'Pianoforti',
#     'description': '',
#     'id': 241,
#     'uuid': '07d56816-232f-48e7-8606-7ed040beab16',
#     'full_name': 'Tastiere e synth / Pianoforti acustici / Pianoforti',
#     'slug': 'grand-pianos',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/grand-pianos'},
#      'listings': {'href': '/api/listings?category=grand-pianos&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/grand-pianos'}}},
#    {'name': 'Pianoforti digitali da palco',
#     'description': '',
#     'id': 478,
#     'uuid': '89de4db0-dab0-48b5-bc66-6580cebb6111',
#     'full_name': 'Tastiere e synth / Pianoforti digitali / Pianoforti digitali da palco',
#     'slug': 'digital-stage-pianos',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/digital-stage-pianos'},
#      'listings': {'href': '/api/listings?category=digital-stage-pianos&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/digital-stage-pianos'}}},
#    {'name': 'Pianoforti digitali domestici',
#     'description': '',
#     'id': 477,
#     'uuid': '04f056db-0b48-49a0-a72e-36386e02f66b',
#     'full_name': 'Tastiere e synth / Pianoforti digitali / Pianoforti digitali domestici',
#     'slug': 'digital-home-pianos',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/digital-home-pianos'},
#      'listings': {'href': '/api/listings?category=digital-home-pianos&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/digital-home-pianos'}}},
#    {'name': 'Pianoforti elettrici',
#     'description': '',
#     'id': 155,
#     'uuid': '148977b8-b308-4364-89fc-95859d2b3bc3',
#     'full_name': 'Tastiere e synth / Pianoforti elettrici',
#     'slug': 'electric-pianos',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/electric-pianos'},
#      'listings': {'href': '/api/listings?category=electric-pianos&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/electric-pianos'}}},
#    {'name': 'Pianoforti verticali',
#     'description': '',
#     'id': 242,
#     'uuid': 'b387f2a1-0781-490a-a3f7-9d1797235cc4',
#     'full_name': 'Tastiere e synth / Pianoforti acustici / Pianoforti verticali',
#     'slug': 'upright-pianos',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/upright-pianos'},
#      'listings': {'href': '/api/listings?category=upright-pianos&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/upright-pianos'}}},
#    {'name': 'Schede DSP per sintetizzatori modulari',
#     'description': '',
#     'id': 459,
#     'uuid': '420a271f-d07d-404f-9904-e5557473fd12',
#     'full_name': 'Tastiere e synth / Accessori per tastiera e synth / Accessori per sintetizzatori modulari / Schede DSP per sintetizzatori modulari',
#     'slug': 'modular-synth-dsp-cards',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/modular-synth-dsp-cards'},
#      'listings': {'href': '/api/listings?category=modular-synth-dsp-cards&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/modular-synth-dsp-cards'}}},
#    {'name': 'Sequencer',
#     'description': '',
#     'id': 467,
#     'uuid': '37c7e49a-9d81-4d03-b14a-e5cb842b8f07',
#     'full_name': 'Tastiere e synth / Sequencer',
#     'slug': 'sequencers',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/sequencers'},
#      'listings': {'href': '/api/listings?category=sequencers&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/sequencers'}}},
#    {'name': 'Sistemi completi di sintetizzatori modulari',
#     'description': '',
#     'id': 462,
#     'uuid': '445d0bc8-781c-46a8-8005-c2881c24a873',
#     'full_name': 'Tastiere e synth / Synth / Synth modulari / Sistemi completi di sintetizzatori modulari',
#     'slug': 'complete-modular-synth-systems',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/complete-modular-synth-systems'},
#      'listings': {'href': '/api/listings?category=complete-modular-synth-systems&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/complete-modular-synth-systems'}}},
#    {'name': 'Splitter/hub per sintetizzatori modulari',
#     'description': '',
#     'id': 461,
#     'uuid': '2f4d155c-264f-4bef-a5a0-8c2b9ce093b2',
#     'full_name': 'Tastiere e synth / Accessori per tastiera e synth / Accessori per sintetizzatori modulari / Splitter/hub per sintetizzatori modulari',
#     'slug': 'modular-synth-splitters-slash-hubs',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/modular-synth-splitters-slash-hubs'},
#      'listings': {'href': '/api/listings?category=modular-synth-splitters-slash-hubs&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/modular-synth-splitters-slash-hubs'}}},
#    {'name': 'Supporti per tastiera e synth',
#     'description': '',
#     'id': 109,
#     'uuid': '64aa38c7-bbe6-4f9f-9df8-179107961d29',
#     'full_name': 'Tastiere e synth / Accessori per tastiera e synth / Supporti per tastiera e synth',
#     'slug': 'keyboard-and-synth-stands',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/keyboard-and-synth-stands'},
#      'listings': {'href': '/api/listings?category=keyboard-and-synth-stands&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/keyboard-and-synth-stands'}}},
#    {'name': 'Synth a rack',
#     'description': '',
#     'id': 106,
#     'uuid': '9854a2b4-5db3-4dfd-85f1-dcb444d5d7f6',
#     'full_name': 'Tastiere e synth / Synth / Synth a rack',
#     'slug': 'rackmount-synths',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/rackmount-synths'},
#      'listings': {'href': '/api/listings?category=rackmount-synths&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/rackmount-synths'}}},
#    {'name': 'Synth analogici',
#     'description': '',
#     'id': 105,
#     'uuid': 'c577b406-a405-45ec-a8eb-56fbe628fa19',
#     'full_name': 'Tastiere e synth / Synth / Synth analogici',
#     'slug': 'analog-synths',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/analog-synths'},
#      'listings': {'href': '/api/listings?category=analog-synths&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/analog-synths'}}},
#    {'name': 'Synth desktop',
#     'description': '',
#     'id': 469,
#     'uuid': '9fc531bd-53df-46fa-8f47-ff1a5b9c7038',
#     'full_name': 'Tastiere e synth / Synth / Synth desktop',
#     'slug': 'desktop-synths',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/desktop-synths'},
#      'listings': {'href': '/api/listings?category=desktop-synths&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/desktop-synths'}}},
#    {'name': 'Synth digitali',
#     'description': '',
#     'id': 139,
#     'uuid': '75b1e4a3-dbb4-46c5-8386-fa18546e097a',
#     'full_name': 'Tastiere e synth / Synth / Synth digitali',
#     'slug': 'digital-synths',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/digital-synths'},
#      'listings': {'href': '/api/listings?category=digital-synths&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/digital-synths'}}},
#    {'name': 'Synth per tastiera',
#     'description': '',
#     'id': 470,
#     'uuid': 'd2688e49-3cca-4cf6-95d0-c105e8e5c3bd',
#     'full_name': 'Tastiere e synth / Synth / Synth per tastiera',
#     'slug': 'keyboard-synths',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/keyboard-synths'},
#      'listings': {'href': '/api/listings?category=keyboard-synths&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/keyboard-synths'}}},
#    {'name': 'Tastiere arranger',
#     'description': '',
#     'id': 465,
#     'uuid': 'f7693392-603e-4e47-bf83-dbe0f586f350',
#     'full_name': 'Tastiere e synth / Tastiere arranger',
#     'slug': 'arranger-keyboards',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/arranger-keyboards'},
#      'listings': {'href': '/api/listings?category=arranger-keyboards&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/arranger-keyboards'}}},
#    {'name': 'Tastiere per workstation',
#     'description': '',
#     'id': 100,
#     'uuid': '4caba01d-fef3-4f67-9c2c-a5116d1faf0a',
#     'full_name': 'Tastiere e synth / Tastiere per workstation',
#     'slug': 'workstation-keyboards',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/workstation-keyboards'},
#      'listings': {'href': '/api/listings?category=workstation-keyboards&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/workstation-keyboards'}}},
#    {'name': 'Tastiere portatili',
#     'description': '',
#     'id': 468,
#     'uuid': 'f540ce2a-6dfa-4d2c-a2d5-5a7f45b2314d',
#     'full_name': 'Tastiere e synth / Tastiere portatili',
#     'slug': 'portable-keyboards',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/portable-keyboards'},
#      'listings': {'href': '/api/listings?category=portable-keyboards&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/portable-keyboards'}}},
#    {'name': 'Vocoder',
#     'description': '',
#     'id': 471,
#     'uuid': 'c93058b0-ee45-4f2e-8193-1e6422ed9255',
#     'full_name': 'Tastiere e synth / Synth / Vocoder',
#     'slug': 'vocoders',
#     'product_type_slug': 'keyboards-and-synths',
#     'root_uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#     '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#      'self': {'href': '/api/categories/keyboards-and-synths/vocoders'},
#      'listings': {'href': '/api/listings?category=vocoders&product_type=keyboards-and-synths'},
#      'follow': {'href': '/api/my/follows/categories/keyboards-and-synths/vocoders'}}}],
#   'id': 19,
#   'uuid': 'd002db05-ab63-4c79-999c-d49bbe8d7739',
#   'slug': 'keyboards-and-synths',
#   '_links': {'image': {'href': 'https://rvb-img.reverb.com/image/upload/s--ZnnYzGcA--/f_auto,t_large/v1434468076/lpywfuuxwqhzypqoiyll.png'},
#    'self': {'href': '/api/categories/keyboards-and-synths'},
#    'listings': {'href': '/api/listings?product_type=keyboards-and-synths'},
#    'follow': {'href': '/api/my/follows/categories/keyboards-and-synths'}}}}

# %%
subcat_list = cat_mapping['bass-guitars']['subcategories']
subcat_mapping = {}

for el in subcat_list:
    subcat_mapping[el['slug']] = el

subcat_mapping
# Out:
# {'4-string': {'name': '4 corde',
#   'description': '',
#   'id': 25,
#   'uuid': 'ac571749-28c7-4eec-a1d9-09dca3cf3e5f',
#   'full_name': 'Bassi / 4 corde',
#   'slug': '4-string',
#   'product_type_slug': 'bass-guitars',
#   'root_uuid': '53a9c7d7-d73d-4e7f-905c-553503e50a90',
#   '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#    'self': {'href': '/api/categories/bass-guitars/4-string'},
#    'listings': {'href': '/api/listings?category=4-string&product_type=bass-guitars'},
#    'follow': {'href': '/api/my/follows/categories/bass-guitars/4-string'}}},
#  '5-string-or-more': {'name': 'A 5 corde o più',
#   'description': '',
#   'id': 26,
#   'uuid': '3178be7d-f1cd-4da5-a606-bf3c1b8e834d',
#   'full_name': 'Bassi / A 5 corde o più',
#   'slug': '5-string-or-more',
#   'product_type_slug': 'bass-guitars',
#   'root_uuid': '53a9c7d7-d73d-4e7f-905c-553503e50a90',
#   '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#    'self': {'href': '/api/categories/bass-guitars/5-string-or-more'},
#    'listings': {'href': '/api/listings?category=5-string-or-more&product_type=bass-guitars'},
#    'follow': {'href': '/api/my/follows/categories/bass-guitars/5-string-or-more'}}},
#  'short-scale': {'name': 'A scala corta',
#   'description': '',
#   'id': 121,
#   'uuid': '07276aa7-6f18-4cae-a691-e6043b002fa4',
#   'full_name': 'Bassi / A scala corta',
#   'slug': 'short-scale',
#   'product_type_slug': 'bass-guitars',
#   'root_uuid': '53a9c7d7-d73d-4e7f-905c-553503e50a90',
#   '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#    'self': {'href': '/api/categories/bass-guitars/short-scale'},
#    'listings': {'href': '/api/listings?category=short-scale&product_type=bass-guitars'},
#    'follow': {'href': '/api/my/follows/categories/bass-guitars/short-scale'}}},
#  'acoustic-bass-guitars': {'name': 'Bassi acustici',
#   'description': '',
#   'id': 28,
#   'uuid': 'bd0f2bd8-714b-4d19-ad87-05c5695a3b02',
#   'full_name': 'Bassi / Bassi acustici',
#   'slug': 'acoustic-bass-guitars',
#   'product_type_slug': 'bass-guitars',
#   'root_uuid': '53a9c7d7-d73d-4e7f-905c-553503e50a90',
#   '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#    'self': {'href': '/api/categories/bass-guitars/acoustic-bass-guitars'},
#    'listings': {'href': '/api/listings?category=acoustic-bass-guitars&product_type=bass-guitars'},
#    'follow': {'href': '/api/my/follows/categories/bass-guitars/acoustic-bass-guitars'}}},
#  'active-electronics': {'name': 'Elettroniche attive',
#   'description': '',
#   'id': 120,
#   'uuid': 'a69d9614-7635-45f4-8fd5-4931ce756655',
#   'full_name': 'Bassi / Elettroniche attive',
#   'slug': 'active-electronics',
#   'product_type_slug': 'bass-guitars',
#   'root_uuid': '53a9c7d7-d73d-4e7f-905c-553503e50a90',
#   '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#    'self': {'href': '/api/categories/bass-guitars/active-electronics'},
#    'listings': {'href': '/api/listings?category=active-electronics&product_type=bass-guitars'},
#    'follow': {'href': '/api/my/follows/categories/bass-guitars/active-electronics'}}},
#  'fretless': {'name': 'Fretless',
#   'description': '',
#   'id': 418,
#   'uuid': '5b9e2d05-0797-4c53-a653-390516aef1e9',
#   'full_name': 'Bassi / Fretless',
#   'slug': 'fretless',
#   'product_type_slug': 'bass-guitars',
#   'root_uuid': '53a9c7d7-d73d-4e7f-905c-553503e50a90',
#   '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#    'self': {'href': '/api/categories/bass-guitars/fretless'},
#    'listings': {'href': '/api/listings?category=fretless&product_type=bass-guitars'},
#    'follow': {'href': '/api/my/follows/categories/bass-guitars/fretless'}}},
#  'left-handed': {'name': 'Per mancini',
#   'description': '',
#   'id': 27,
#   'uuid': '0cd005a7-90ce-4f51-8e3c-b7acc4fa82f0',
#   'full_name': 'Bassi / Per mancini',
#   'slug': 'left-handed',
#   'product_type_slug': 'bass-guitars',
#   'root_uuid': '53a9c7d7-d73d-4e7f-905c-553503e50a90',
#   '_links': {'image': {'href': 'https://static.reverb-assets.com/assets/products/blank_medium-8120dba69a21448fa293fc2df8f8ce0265daa804f2be9a7413732a58d1b833f8.jpg'},
#    'self': {'href': '/api/categories/bass-guitars/left-handed'},
#    'listings': {'href': '/api/listings?category=left-handed&product_type=bass-guitars'},
#    'follow': {'href': '/api/my/follows/categories/bass-guitars/left-handed'}}}}

# %%
cat_mapping = {}

for el in data:  # data = raw["categories"]
    # build mapping for subcategories
    subcat_mapping = {sub["slug"]: sub for sub in el.get("subcategories", [])}
    
    # put into main mapping keyed by top-level slug (if present)
    cat_mapping[el["slug"] if "slug" in el else el["name"]] = {
        **el,
        "subcat_mapping": subcat_mapping
    }

# %%
cat_mapping['bass-guitars']['subcat_mapping']['4-string']['_links']['listings']['href']
# Out:
# '/api/listings?category=4-string&product_type=bass-guitars'

# %%
rows = []
for cat in cat_mapping.keys():
    category = cat
    for subcat in cat_mapping[cat]['subcat_mapping'].keys():
        link = cat_mapping[cat]['subcat_mapping'][subcat]['_links']['listings']['href']
        category = cat
        subcategory = subcat

        rows.append((category, subcategory, link))

df = pd.DataFrame(rows, columns=['product_type', 'category', 'listings_href'])

# %%
df
# Out:
#              product_type               category  \
# 0             accessories                 tuners
# 1             accessories         power-supplies
# 2             accessories          other-strings
# 3             accessories          bass-gig-bags
# 4             accessories        guitar-gig-bags
# ..                    ...                    ...
# 301  keyboards-and-synths        keyboard-synths
# 302  keyboards-and-synths     arranger-keyboards
# 303  keyboards-and-synths  workstation-keyboards
# 304  keyboards-and-synths     portable-keyboards
# 305  keyboards-and-synths               vocoders
#
#                                          listings_href
# 0    /api/listings?category=tuners&product_type=acc...
# 1    /api/listings?category=power-supplies&product_...
# 2    /api/listings?category=other-strings&product_t...
# 3    /api/listings?category=bass-gig-bags&product_t...
# 4    /api/listings?category=guitar-gig-bags&product...
# ..                                                 ...
# 301  /api/listings?category=keyboard-synths&product...
# 302  /api/listings?category=arranger-keyboards&prod...
# 303  /api/listings?category=workstation-keyboards&p...
# 304  /api/listings?category=portable-keyboards&prod...
# 305  /api/listings?category=vocoders&product_type=k...
#
# [306 rows x 3 columns]

# %%
df.to_csv("data/cat-subcat-href_table.csv", index=False)

# %%
import pandas as pd

# Read the parquet file
df = pd.read_parquet("/Users/andrea/Progetti/pulsewave/data/reverb/test/used-IT/combined_dataset.parquet")

# Basic inspection
print(f"Shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
print(df.head())
print(df.info())

# Check data types
print(df.dtypes)

# Look for any null values
print(df.isnull().sum())
df

pd.set_option('display.max_rows', 500)
# Out:
# Shape: (164441, 29)
# Columns: ['id', 'make', 'model', 'finish', 'year', 'sku', 'product_type', 'category', 'title', 'created_at', 'shop_slug', 'preferred_seller', 'condition', 'offers_enabled', 'has_inventory', 'inventory', 'published_at', 'state', 'auction', 'permalink', 'price', 'price_currency', 'price_taxIncluded', 'buyer_price', 'buyer_price_currency', 'buyer_price_taxIncluded', 'snap_valid_from', 'snap_valid_to', 'snap_is_current']
#          id         make              model finish year sku      product_type  \
# 0  92046426        Kirov           Melodiya                  folk-instruments
# 1  92046420      Belarus            Belarus                  folk-instruments
# 2  92046404  Weltmeister        Weltmeister                  folk-instruments
# 3  92046388       Kungur             Kungur                  folk-instruments
# 4  92046154  Weltmeister  Weltmeister Diana                  folk-instruments
#
#      category                                              title  \
# 0  harmonicas  Russian Bayan Melodiya Kirov, Vintage Chromati...
# 1  harmonicas  Russian Bayan Belarus 3 Row Chromatic Button A...
# 2  harmonicas  Weltmeister 96 Bass Accordion made in Germany,...
# 3  harmonicas  Russian Bayan Kungur 100 bass, 3 Row Chromatic...
# 4  harmonicas  Weltmeister Diana Accordion 120 Bass, German A...
#
#                  created_at  ...  \
# 0 2025-09-02 10:33:16+00:00  ...
# 1 2025-09-02 10:30:48+00:00  ...
# 2 2025-09-02 10:26:41+00:00  ...
# 3 2025-09-02 10:24:04+00:00  ...
# 4 2025-09-02 09:42:46+00:00  ...
#
#                                            permalink   price price_currency  \
# 0  https://reverb.com/api/listings/92046426-russi...  384.90            EUR
# 1  https://reverb.com/api/listings/92046420-russi...  349.01            EUR
# 2  https://reverb.com/api/listings/92046404-weltm...  697.13            EUR
# 3  https://reverb.com/api/listings/92046388-russi...  357.98            EUR
# 4  https://reverb.com/api/listings/92046154-weltm...  833.50            EUR
#
#    price_taxIncluded  buyer_price  buyer_price_currency  \
# 0              False       354.11                   EUR
# 1              False       321.09                   EUR
# 2              False       641.36                   EUR
# 3              False       329.35                   EUR
# 4              False       766.82                   EUR
#
#   buyer_price_taxIncluded                  snap_valid_from  snap_valid_to  \
# 0                   False 2025-09-03 12:57:27.083225+00:00            NaT
# 1                   False 2025-09-03 12:57:27.083225+00:00            NaT
# 2                   False 2025-09-03 12:57:27.083225+00:00            NaT
# 3                   False 2025-09-03 12:57:27.083225+00:00            NaT
# 4                   False 2025-09-03 12:57:27.083225+00:00            NaT
#
#   snap_is_current
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
#
# [5 rows x 29 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164441 entries, 0 to 164440
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       164441 non-null  int64
#  1   make                     164441 non-null  object
#  2   model                    164441 non-null  object
#  3   finish                   164441 non-null  object
#  4   year                     164441 non-null  object
#  5   sku                      164441 non-null  object
#  6   product_type             164441 non-null  object
#  7   category                 164441 non-null  object
#  8   title                    164441 non-null  object
#  9   created_at               164441 non-null  datetime64[ns, UTC]
#  10  shop_slug                164441 non-null  object
#  11  preferred_seller         164441 non-null  bool
#  12  condition                164441 non-null  object
#  13  offers_enabled           164441 non-null  bool
#  14  has_inventory            164441 non-null  bool
#  15  inventory                164441 non-null  int64
#  16  published_at             164441 non-null  datetime64[ns, UTC]
#  17  state                    164441 non-null  object
#  18  auction                  164441 non-null  bool
#  19  permalink                164441 non-null  object
#  20  price                    164441 non-null  object
#  21  price_currency           164441 non-null  object
#  22  price_taxIncluded        164441 non-null  bool
#  23  buyer_price              164441 non-null  object
#  24  buyer_price_currency     164441 non-null  object
#  25  buyer_price_taxIncluded  164441 non-null  bool
#  26  snap_valid_from          164441 non-null  datetime64[ns, UTC]
#  27  snap_valid_to            31 non-null      datetime64[us, UTC]
#  28  snap_is_current          164441 non-null  bool
# dtypes: bool(7), datetime64[ns, UTC](3), datetime64[us, UTC](1), int64(2), object(16)
# memory usage: 28.7+ MB
# None
# id                                       int64
# make                                    object
# model                                   object
# finish                                  object
# year                                    object
# sku                                     object
# product_type                            object
# category                                object
# title                                   object
# created_at                 datetime64[ns, UTC]
# shop_slug                               object
# preferred_seller                          bool
# condition                               object
# offers_enabled                            bool
# has_inventory                             bool
# inventory                                int64
# published_at               datetime64[ns, UTC]
# state                                   object
# auction                                   bool
# permalink                               object
# price                                   object
# price_currency                          object
# price_taxIncluded                         bool
# buyer_price                             object
# buyer_price_currency                    object
# buyer_price_taxIncluded                   bool
# snap_valid_from            datetime64[ns, UTC]
# snap_valid_to              datetime64[us, UTC]
# snap_is_current                           bool
# dtype: object
# id                              0
# make                            0
# model                           0
# finish                          0
# year                            0
# sku                             0
# product_type                    0
# category                        0
# title                           0
# created_at                      0
# shop_slug                       0
# preferred_seller                0
# condition                       0
# offers_enabled                  0
# has_inventory                   0
# inventory                       0
# published_at                    0
# state                           0
# auction                         0
# permalink                       0
# price                           0
# price_currency                  0
# price_taxIncluded               0
# buyer_price                     0
# buyer_price_currency            0
# buyer_price_taxIncluded         0
# snap_valid_from                 0
# snap_valid_to              164410
# snap_is_current                 0
# dtype: int64

# %%
len(df)
# Out:
# 164441

# %%
df
# Out:
#               id         make                            model  \
# 0       92046426        Kirov                         Melodiya
# 1       92046420      Belarus                          Belarus
# 2       92046404  Weltmeister                      Weltmeister
# 3       92046388       Kungur                           Kungur
# 4       92046154  Weltmeister                Weltmeister Diana
# ...          ...          ...                              ...
# 164436  75254042    Bill Cahn  Xylo-Duck Model #XD-1 Duck Call
# 164437  63889197       Yamaha                SPK-285 Xylophone
# 164438  63880851       Yamaha                SPK-275 Xylophone
# 164439  57692010      Vintage                        Xylophone
# 164440   5826752    Vic Firth                             m132
#
#                      finish year           sku          product_type  \
# 0                                                   folk-instruments
# 1                                                   folk-instruments
# 2                                                   folk-instruments
# 3                                                   folk-instruments
# 4                                                   folk-instruments
# ...                     ...  ...           ...                   ...
# 164436                                          drums-and-percussion
# 164437                            rev-63889197  drums-and-percussion
# 164438                            rev-63880851  drums-and-percussion
# 164439  White / Black / Red                     drums-and-percussion
# 164440                             rev-5826752  drums-and-percussion
#
#           category                                              title  \
# 0       harmonicas  Russian Bayan Melodiya Kirov, Vintage Chromati...
# 1       harmonicas  Russian Bayan Belarus 3 Row Chromatic Button A...
# 2       harmonicas  Weltmeister 96 Bass Accordion made in Germany,...
# 3       harmonicas  Russian Bayan Kungur 100 bass, 3 Row Chromatic...
# 4       harmonicas  Weltmeister Diana Accordion 120 Bass, German A...
# ...            ...                                                ...
# 164436  xylophones          Bill Cahn Xylo-Duck Model #XD-1 Duck Call
# 164437  xylophones        Yamaha SPK-285 Xylophone with case, Taiwan.
# 164438  xylophones                           Yamaha SPK-275 Xylophone
# 164439  xylophones                                  Vintage Xylophone
# 164440  xylophones                              Vic Firth M132 Mallet
#
#                       created_at  ...  \
# 0      2025-09-02 10:33:16+00:00  ...
# 1      2025-09-02 10:30:48+00:00  ...
# 2      2025-09-02 10:26:41+00:00  ...
# 3      2025-09-02 10:24:04+00:00  ...
# 4      2025-09-02 09:42:46+00:00  ...
# ...                          ...  ...
# 164436 2023-10-30 22:17:06+00:00  ...
# 164437 2022-12-07 04:27:03+00:00  ...
# 164438 2022-12-06 23:04:16+00:00  ...
# 164439 2022-07-12 08:55:20+00:00  ...
# 164440 2017-07-04 19:15:53+00:00  ...
#
#                                                 permalink   price  \
# 0       https://reverb.com/api/listings/92046426-russi...  384.90
# 1       https://reverb.com/api/listings/92046420-russi...  349.01
# 2       https://reverb.com/api/listings/92046404-weltm...  697.13
# 3       https://reverb.com/api/listings/92046388-russi...  357.98
# 4       https://reverb.com/api/listings/92046154-weltm...  833.50
# ...                                                   ...     ...
# 164436  https://reverb.com/api/listings/75254042-bill-...   76.61
# 164437  https://reverb.com/api/listings/63889197-yamah...  178.54
# 164438  https://reverb.com/api/listings/63880851-yamah...  178.54
# 164439  https://reverb.com/api/listings/57692010-vinta...   70.00
# 164440  https://reverb.com/api/listings/5826752-vic-fi...   26.24
#
#        price_currency  price_taxIncluded  buyer_price  buyer_price_currency  \
# 0                 EUR              False       354.11                   EUR
# 1                 EUR              False       321.09                   EUR
# 2                 EUR              False       641.36                   EUR
# 3                 EUR              False       329.35                   EUR
# 4                 EUR              False       766.82                   EUR
# ...               ...                ...          ...                   ...
# 164436            EUR               True        76.61                   EUR
# 164437            EUR              False       178.54                   EUR
# 164438            EUR              False       178.54                   EUR
# 164439            EUR              False        70.00                   EUR
# 164440            EUR               True        26.24                   EUR
#
#        buyer_price_taxIncluded                  snap_valid_from  \
# 0                        False 2025-09-03 12:57:27.083225+00:00
# 1                        False 2025-09-03 12:57:27.083225+00:00
# 2                        False 2025-09-03 12:57:27.083225+00:00
# 3                        False 2025-09-03 12:57:27.083225+00:00
# 4                        False 2025-09-03 12:57:27.083225+00:00
# ...                        ...                              ...
# 164436                    True 2025-09-03 12:57:27.083225+00:00
# 164437                   False 2025-09-03 12:57:27.083225+00:00
# 164438                   False 2025-09-03 12:57:27.083225+00:00
# 164439                   False 2025-09-03 12:57:27.083225+00:00
# 164440                    True 2025-09-03 12:57:27.083225+00:00
#
#         snap_valid_to snap_is_current
# 0                 NaT            True
# 1                 NaT            True
# 2                 NaT            True
# 3                 NaT            True
# 4                 NaT            True
# ...               ...             ...
# 164436            NaT            True
# 164437            NaT            True
# 164438            NaT            True
# 164439            NaT            True
# 164440            NaT            True
#
# [164441 rows x 29 columns]
